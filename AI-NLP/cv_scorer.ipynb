# %%
# CV pdf'i okuma:
import pdfplumber

def extract_pdf_text(pdf_path):
    all_text = ""

    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                all_text += text + "\n"

    return all_text

pdf_text = extract_pdf_text("ErayInalCV.pdf")
print(pdf_text)
# Out:
# ERAY İNAL
# Computer Engineering Student
# CONTACT Email: erayinaal@gmail.com LinkedIn: https://www.linkedin.com/in/erayinal/
# Phone: +90 (552) 323 37 29 GitHub: https://github.com/erayinal
# ABOUT Final-year Computer Engineering student focused on Artificial Intelligence and Data Science. My
# academic background and project experience have strengthened my interest in applied machine
# learning, natural language processing, and statistical modeling. I aspire to pursue research and real-
# world applications that leverage AI to enhance decision-making and human-computer interaction.
# PROFESSIONAL Work and Travel | USA | May 2025 - Sep 2025 (4 Months)
# EXPERIENCE
# Operated amusement park rides while ensuring strict adherence to safety protocols and operational
# procedures.
# Monitored ride performance and responded promptly to operational or safety issues to ensure continuous,
# safe, and enjoyable guest experiences.
# ...

# %%
# CV “skills” bölümünü çekme
import re

skills = re.findall(r"Skills[:\-]?\s*(.*)", pdf_text, flags=re.IGNORECASE)
print(skills)
# Out:
# ['through daily interactions', 'Java (Upper-Intermediate) Database Management(SQL)']

# %%
# Deneyim:
experience_section = re.split(r"Experience|Work Experience", pdf_text, flags=re.IGNORECASE)[-1]
print(experience_section)
# Out:
# s.
# Enhanced teamwork and problem-solving abilities by collaborating with team members to handle large
# crowds and maintain smooth ride operations during peak hours.
# Strengthened English fluency, cross-cultural communication, and interpersonal skills through daily interactions
# with guests and coworkers from diverse cultural backgrounds.
# Java Programming Instructor | Bucharest, Romania | Summer 2024
# Designed and delivered Java programming sessions progressing from basics to more complex topics.
# Provided hands-on training through coding exercises and interactive sessions.
# Mentored students to successfully complete individual and group programming projects.
# EDUCATION Akdeniz University | 2021-2026
# Bachelor of Computer Engineering
# Current Status: fourth-year student
# Language of instruction: English
# PROJECTS KonumLA
# MVVM, Firebase, CoreData, CoreLocation, MapKit, SPM
# CryptoBloom
# MVVM, RxSwift, Binding, API
# InstagramClone
# MVVM, RxSwift, Binding, API
# ...

# %% [markdown]
# ### Vektorization ve AI ile
#
# * We worked on the text in pdf up to this point. But from now on, we are going to analyse it by vectorizing it. Thus:
#     * "What are this person's strong technical skills?"
#     * AI generates meaningful answers based on the CV content.
#     * This works like a real 'AI HR Screening'
#
# * Now, let's do an analyse for strengths/weaknesses below:

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyC9ydt_SYAzSo54CVuRwl4VpR1HruMRXxU")
model = genai.GenerativeModel("models/gemini-flash-latest")

# %%
def analyze_cv_strengths_weaknesses(cv_text: str) -> str:
    """
    Verilen CV metni üzerinden AI ile güçlü yönler, zayıf yönler ve kısa bir özet üretir.
    Çıktı: Türkçe, madde madde ve okunaklı formatta.
    """
    prompt = f"""
Sen deneyimli bir insan kaynakları (HR) uzmanısın. Görevin, aşağıdaki CV metnini
inceleyip adayın güçlü ve zayıf yönlerini analiz etmek.

Lütfen şu formatta cevap ver:
1) Güçlü Yönler:
- ...

2) Zayıf Yönler:
- ...

3) Genel Değerlendirme (Kısa Özet, 3–5 cümle):
- ...

Notlar:
- Cevabın TÜRKÇE olsun.
- Lütfen CV'de yazmayan şeyleri UYDURMA.
- Emin olmadığın noktalar için "CV'den net anlaşılmıyor" gibi ifadeler kullan.

CV METNİ:
\"\"\"{cv_text}\"\"\"
"""

    response = model.generate_content(prompt)
    return response.text

# %%
strengths_result = analyze_cv_strengths_weaknesses(pdf_text)
print(strengths_result)
# Out:
# Bu analizi, Eray İnal'ın Yapay Zeka ve Veri Bilimi alanlarına odaklanan bir Bilgisayar Mühendisliği öğrencisi olduğu varsayımıyla, teknik bir rol için değerlendirme amacıyla sunuyorum.
#
# ---
#
# ## ERAY İNAL - CV ANALİZİ
#
# ### 1) Güçlü Yönler:
#
# *   **Net Kariyer Odaklanması:** Adayın 'Hakkında' bölümünde Yapay Zeka, Doğal Dil İşleme (NLP) ve Uygulamalı Makine Öğrenimi alanlarına olan ilgisini net bir şekilde belirtmesi, kariyer hedeflerinin belirgin olduğunu gösterir.
# *   **Kanıtlanmış Teknik İletişim ve Mentorluk Yeteneği:** Romanya’da Java Programlama Eğitmeni olarak görev yapması, adayın teknik bilgiyi yapılandırılmış bir şekilde aktarabilme, eğitim materyali tasarlama ve öğrencilere rehberlik etme yeteneğine sahip olduğunu kanıtlar. Bu, gelecekteki ekip içi bilgi paylaşımı ve liderlik potansiyeli için önemli bir artıdır.
# ...

# %%
def score_cv_for_role(cv_text: str, job_description: str) -> str:
    """
    Generates a suitability score and explanation from AI based on the CV text and job description.
    """
    prompt = f"""
You are an experienced Human Resources and Technical Recruitment Specialist.
Below, a JOB DESCRIPTION and a CANDIDATE CV will be provided.

Your Task:
1) Score the candidate's suitability for this position between 0-100.
2) List the strong matching aspects (skills, experience, education) as bullet points.
3) List missing or weak aspects as bullet points.
4) Add a short general comment at the end.

Please answer in the following format:

Suitability Score: XX/100

Key Strengths:
- ...

Weaknesses / Gaps:
- ...

General Comment:
- ...

Notes:
- Ensure the response is in ENGLISH.
- Please evaluate based ONLY on the provided job description and CV.
- Do not add fabricated information or hallucinations.

JOB DESCRIPTION:
\"\"\"{job_description}\"\"\"

CANDIDATE CV TEXT:
\"\"\"{cv_text}\"\"\"
"""
    
    response = model.generate_content(prompt)
    return response.text

# %%
job_description = """
Pozisyon: Junior Data Analyst

Aranan Nitelikler:
- İyi düzeyde Python bilgisi
- SQL ile veri sorgulama deneyimi
- Temel istatistik ve veri analizi bilgisi
- Tercihen pandas veya benzeri kütüphanelerle çalışma deneyimi
- İngilizce doküman okuyabilecek seviyede olması

Sorumluluklar:
- Veri temizleme, düzenleme ve raporlama
- Dashboard ve rapor hazırlanmasına destek olmak
- İş birimlerinden gelen veri analiz taleplerine cevap vermek
"""

# %%
score_result = score_cv_for_role(pdf_text, job_description)
print(score_result)
# Out:
# Suitability Score: 75/100
#
# Key Strengths:
# -   **Python Proficiency:** Candidate lists Python as 'Upper-Intermediate,' directly addressing the requirement for "İyi düzeyde Python bilgisi."
# -   **SQL Knowledge:** The CV lists 'Database Management (SQL)' as a relevant skill, meeting the requirement for "SQL ile veri sorgulama deneyimi."
# -   **Foundational Knowledge:** Possesses a foundation in data analysis and basic statistics, supported by the ongoing Computer Engineering degree and the completion of the Techcareer.net "Veri Bilimi 101 Bootcamp."
# -   **English Language:** Candidate lists English as 'Advanced' and is studying in an English-language instruction program, easily meeting the requirement to read technical documentation.
# -   **Analytical Skills:** Analytical thinking is explicitly listed as a skill.
# -   **Role Alignment:** The candidate is a final-year student seeking AI/Data Science focus, aligning well with a Junior position.
#
# Weaknesses / Gaps:
# ...
